# %%
import pandas as pd
import pymysql
from sklearn.cluster import AgglomerativeClustering as AC

# %%
connection = pymysql.connect(host="us-cdbr-iron-east-03.cleardb.net",
              user="bb8507107bd736",
              password="89bc7c14",
              db="heroku_94b4589a90ac9bc")

df = pd.read_sql("SELECT * FROM final_pitching_table", connection)
df.head()
# Out:
#     IP   SO   ER    W  IP_Avg    SO_Avg    ER_Avg     W_Avg   BatAvg1  \
# 0  6.0  4.0  1.0  0.0    5.05  4.250000  6.242500  0.250000  0.279591
# 1  6.0  4.0  2.0  0.0    5.70  5.333333  1.046667  0.666667  0.719200
# 2  5.0  5.0  3.0  0.0    5.86  4.600000  3.674000  0.200000  0.719200
# 3  6.0  4.0  4.0  1.0    6.22  3.600000  4.652000  0.600000  0.242346
# 4  4.0  7.0  5.0  0.0    6.02  4.200000  3.168000  0.400000  0.248889
#
#     BatAvg2  ...   BatAvg9  FieldAvg1  FieldAvg2  FieldAvg3  FieldAvg4  \
# 0  0.320348  ...  0.159143   0.989956   1.000000   0.984636   0.989542
# 1  0.404316  ...  0.186857   1.000000   1.000000   0.994522   0.846087
# 2  0.202087  ...  0.315400   1.000000   1.000000   0.994522   0.846087
# 3  0.279393  ...  0.244731   0.971111   0.998185   0.994333   1.000000
# 4  0.285929  ...  0.247348   0.995217   1.000000   0.981500   1.000000
#
#    FieldAvg5  FieldAvg6  FieldAvg7  FieldAvg8  FieldAvg9
# 0   1.000000   0.954143   0.991176   0.944316   1.000000
# 1   0.975533   1.000000   0.997333   1.000000   1.000000
# 2   0.994783   1.000000   0.997333   0.992312   1.000000
# 3   1.000000   0.928964   1.000000   0.940227   0.976903
# 4   1.000000   0.989280   0.995000   1.000000   1.000000
#
# [5 rows x 26 columns]

# %% [markdown]
# Get correlation of the dependent variables against every other variable.

# %%
df.corr()[['IP','SO','ER','W']]
# Out:
#                  IP        SO        ER         W
# IP         1.000000  0.423307 -0.439820  0.416834
# SO         0.423307  1.000000 -0.245760  0.257580
# ER        -0.439820 -0.245760  1.000000 -0.415735
# W          0.416834  0.257580 -0.415735  1.000000
# IP_Avg     0.254796  0.155030  0.028856  0.067351
# SO_Avg     0.159163  0.362263 -0.102517  0.094667
# ER_Avg    -0.057133 -0.094146 -0.011792  0.053238
# W_Avg      0.035137  0.062354  0.071024 -0.044197
# BatAvg1    0.004478 -0.035486  0.041874 -0.018587
# BatAvg2   -0.018131 -0.046754  0.060384 -0.009154
# BatAvg3   -0.001848 -0.039646  0.027295 -0.016052
# BatAvg4   -0.008234  0.001010  0.032553  0.015371
# BatAvg5    0.008082  0.018725 -0.004751  0.019374
# BatAvg6    0.001602 -0.005584 -0.015450  0.044237
# BatAvg7   -0.017497 -0.039896 -0.000513 -0.010462
# BatAvg8   -0.007043 -0.032575  0.040259 -0.020532
# BatAvg9   -0.011024 -0.026377  0.069802 -0.021184
# FieldAvg1  0.027351  0.003799  0.062636 -0.052695
# FieldAvg2 -0.023374 -0.051488  0.007204 -0.049417
# FieldAvg3  0.013867  0.087781  0.015403  0.029528
# FieldAvg4  0.027409 -0.007347  0.011504 -0.011160
# FieldAvg5  0.095182  0.009160 -0.044846  0.045327
# FieldAvg6  0.134118  0.067515 -0.013363  0.058182
# FieldAvg7  0.057008  0.057139 -0.035284  0.000323
# FieldAvg8 -0.014459 -0.061392  0.041375 -0.002688
# FieldAvg9  0.000802  0.023184  0.045834 -0.042067

# %%
dep_var_cluster = AC(n_clusters=4).fit(df[['IP','SO','ER','W']])

dep_var_cluster
# Out:
# AgglomerativeClustering(affinity='euclidean', compute_full_tree='auto',
#             connectivity=None, linkage='ward', memory=None, n_clusters=4,
#             pooling_func='deprecated')
